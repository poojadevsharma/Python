# %%
import pandas as pd

# %%
df = pd.read_excel('duplicate.xlsx')
df
# Out:
#        name  age  phone  adhar   city
# 0       raj   23   1234   5467  noida
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 3    himesh   23   2345   4567  noida
# 4  dharmesh   45   1234   4567  noida
# 5  dharmesh   45   1234   4567  noida
# 6    suresh   67   2341   4567  delhi

# %%
df.loc[   df.duplicated(subset='phone')   ]
# Out:
#        name  age  phone  adhar   city
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 4  dharmesh   45   1234   4567  noida
# 5  dharmesh   45   1234   4567  noida

# %%
df.loc[   df.duplicated(subset='phone',keep='last')   ]
# Out:
#        name  age  phone  adhar   city
# 0       raj   23   1234   5467  noida
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 4  dharmesh   45   1234   4567  noida

# %%
df.loc[   df.duplicated(subset='phone',keep=False)   ]
# Out:
#        name  age  phone  adhar   city
# 0       raj   23   1234   5467  noida
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 4  dharmesh   45   1234   4567  noida
# 5  dharmesh   45   1234   4567  noida

# %%
df.drop_duplicates(subset='phone',keep=False)
# Out:
#      name  age  phone  adhar   city
# 3  himesh   23   2345   4567  noida
# 6  suresh   67   2341   4567  delhi

# %%
df
# Out:
#        name  age  phone  adhar   city
# 0       raj   23   1234   5467  noida
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 3    himesh   23   2345   4567  noida
# 4  dharmesh   45   1234   4567  noida
# 5  dharmesh   45   1234   4567  noida
# 6    suresh   67   2341   4567  delhi

# %%
df.duplicated(subset = ['name','age','phone','city','adhar'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
df.loc[ df.duplicated(keep=False) ]
# Out:
#        name  age  phone  adhar   city
# 1    suresh   23   1234   4567  noida
# 2    suresh   23   1234   4567  noida
# 4  dharmesh   45   1234   4567  noida
# 5  dharmesh   45   1234   4567  noida
