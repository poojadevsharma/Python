# %% [markdown]
# # Advanced Filtering

# %%
import pandas as pd

# %%
df = pd.read_excel('amazon.xlsx')
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %% [markdown]
# ### Suppose you have a manager. If Profit is greater than 1000, Target Column is Achieved else Target Column Not Achieved

# %%
df['target'] = 'Achieved'
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %%
df.loc[df['Profit']<=500,'target'] = 'Not Achieved'
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %% [markdown]
# ## Advanced Filtering Part 1 - index

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %%
df.loc[0]
# Out:
# Order ID                                            CA-2012-124891
# Order Date                                     2012-07-31 00:00:00
# Ship Date                                      2012-07-31 00:00:00
# Ship Mode                                                 Same Day
# Customer ID                                               RH-19495
# Customer Name                                          Rick Hansen
# Customer Type                                             Consumer
# City                                                 New York City
# State                                                     New York
# Country                                              United States
# Product Type                                            Technology
# Product                                                Accessories
# Product Name     Plantronics CS510 - Over-the-Head monaural Wir...
# Sales                                                      2309.65
# ...

# %%
df.loc[ [0,2,3,5,7] ]
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 2    IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3  ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 5    IN-2013-42360 2013-06-28 2013-07-01    Second Class    JM-15655
# 7    IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
#
#       Customer Name Customer Type           City            State  \
# 0       Rick Hansen      Consumer  New York City         New York
# 2      Craig Reiter      Consumer       Brisbane       Queensland
# 3  Katherine Murray   Home Office         Berlin           Berlin
# 5       Jim Mitchum     Corporate         Sydney  New South Wales
# 7        Mick Brown      Consumer       Hamilton          Waikato
#
#          Country Product Type      Product  \
# 0  United States   Technology  Accessories
# 2      Australia   Technology       Phones
# ...

# %% [markdown]
# ## set_index - convert any column to index

# %%
df = df.set_index('Customer Type')
df
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# Customer Type
# Consumer        CA-2012-124891 2012-07-31 2012-07-31        Same Day
# Corporate        IN-2013-77878 2013-02-05 2013-02-07    Second Class
# Consumer         IN-2013-71249 2013-10-17 2013-10-18     First Class
# Home Office    ES-2013-1579342 2013-01-28 2013-01-30     First Class
# Consumer          SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...                        ...        ...        ...             ...
# Corporate       CA-2013-101546 2013-12-19 2013-12-25  Standard Class
# Corporate       CA-2014-154410 2014-10-22 2014-10-25     First Class
# Home Office      ID-2012-31118 2012-12-26 2012-12-28    Second Class
# Home Office      IN-2013-65677 2013-10-11 2013-10-14     First Class
# Consumer         ID-2012-39875 2012-04-25 2012-04-27    Second Class
#
#               Customer ID      Customer Name           City            State  \
# Customer Type
# ...

# %% [markdown]
# ## reset_index - Reset index to 0 1 2 3

# %%
ndf= df.loc['Consumer']
ndf = ndf.reset_index()
ndf
# Out:
#     Customer Type         Order ID Order Date  Ship Date       Ship Mode  \
# 0        Consumer   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1        Consumer    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 2        Consumer     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# 3        Consumer    IN-2011-81826 2011-11-07 2011-11-09     First Class
# 4        Consumer    IN-2012-86369 2012-04-14 2012-04-18  Standard Class
# ..            ...              ...        ...        ...             ...
# 412      Consumer     IV-2014-5230 2014-12-10 2014-12-13    Second Class
# 413      Consumer   CA-2013-165330 2013-12-12 2013-12-12        Same Day
# 414      Consumer  ES-2014-5218647 2014-04-14 2014-04-18  Standard Class
# 415      Consumer    IN-2013-10811 2013-09-17 2013-09-20     First Class
# 416      Consumer    ID-2012-39875 2012-04-25 2012-04-27    Second Class
#
#     Customer ID     Customer Name           City           State  \
# ...

# %% [markdown]
# # Task

# %%
df = df.reset_index()
df
# Out:
#     Customer Type         Order ID Order Date  Ship Date       Ship Mode  \
# 0        Consumer   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       Corporate    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2        Consumer    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3     Home Office  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4        Consumer     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ..            ...              ...        ...        ...             ...
# 823     Corporate   CA-2013-101546 2013-12-19 2013-12-25  Standard Class
# 824     Corporate   CA-2014-154410 2014-10-22 2014-10-25     First Class
# 825   Home Office    ID-2012-31118 2012-12-26 2012-12-28    Second Class
# 826   Home Office    IN-2013-65677 2013-10-11 2013-10-14     First Class
# 827      Consumer    ID-2012-39875 2012-04-25 2012-04-27    Second Class
#
#     Customer ID      Customer Name           City            State  \
# ...

# %%
df = df.set_index('Country')
df.loc['United States'].reset_index()
# Out:
#            Country Customer Type        Order ID Order Date  Ship Date  \
# 0    United States      Consumer  CA-2012-124891 2012-07-31 2012-07-31
# 1    United States     Corporate  CA-2014-135909 2014-10-14 2014-10-21
# 2    United States      Consumer  CA-2012-116638 2012-01-28 2012-01-31
# 3    United States     Corporate  CA-2011-102988 2011-04-05 2011-04-09
# 4    United States     Corporate  CA-2014-143567 2014-11-03 2014-11-06
# ..             ...           ...             ...        ...        ...
# 156  United States      Consumer  CA-2014-116680 2014-09-05 2014-09-07
# 157  United States   Home Office  CA-2014-157966 2014-03-14 2014-03-14
# 158  United States      Consumer  CA-2013-165330 2013-12-12 2013-12-12
# 159  United States     Corporate  CA-2013-101546 2013-12-19 2013-12-25
# 160  United States     Corporate  CA-2014-154410 2014-10-22 2014-10-25
#
#           Ship Mode Customer ID       Customer Name           City  \
# ...

# %% [markdown]
# Task - Consumer and Corporate

# %%
df = df.reset_index()
df
# Out:
#            Country Customer Type         Order ID Order Date  Ship Date  \
# 0    United States      Consumer   CA-2012-124891 2012-07-31 2012-07-31
# 1        Australia     Corporate    IN-2013-77878 2013-02-05 2013-02-07
# 2        Australia      Consumer    IN-2013-71249 2013-10-17 2013-10-18
# 3          Germany   Home Office  ES-2013-1579342 2013-01-28 2013-01-30
# 4          Senegal      Consumer     SG-2013-4320 2013-11-05 2013-11-06
# ..             ...           ...              ...        ...        ...
# 823  United States     Corporate   CA-2013-101546 2013-12-19 2013-12-25
# 824  United States     Corporate   CA-2014-154410 2014-10-22 2014-10-25
# 825       Thailand   Home Office    ID-2012-31118 2012-12-26 2012-12-28
# 826          China   Home Office    IN-2013-65677 2013-10-11 2013-10-14
# 827          China      Consumer    ID-2012-39875 2012-04-25 2012-04-27
#
#           Ship Mode Customer ID      Customer Name           City  \
# ...

# %%
df = df.set_index('Customer Type')
df
# Out:
#                      Country         Order ID Order Date  Ship Date  \
# Customer Type
# Consumer       United States   CA-2012-124891 2012-07-31 2012-07-31
# Corporate          Australia    IN-2013-77878 2013-02-05 2013-02-07
# Consumer           Australia    IN-2013-71249 2013-10-17 2013-10-18
# Home Office          Germany  ES-2013-1579342 2013-01-28 2013-01-30
# Consumer             Senegal     SG-2013-4320 2013-11-05 2013-11-06
# ...                      ...              ...        ...        ...
# Corporate      United States   CA-2013-101546 2013-12-19 2013-12-25
# Corporate      United States   CA-2014-154410 2014-10-22 2014-10-25
# Home Office         Thailand    ID-2012-31118 2012-12-26 2012-12-28
# Home Office            China    IN-2013-65677 2013-10-11 2013-10-14
# Consumer               China    ID-2012-39875 2012-04-25 2012-04-27
#
#                     Ship Mode Customer ID      Customer Name           City  \
# Customer Type
# ...

# %%
df.loc[ ['Consumer','Corporate']  ]
# Out:
#                      Country         Order ID Order Date  Ship Date  \
# Customer Type
# Consumer       United States   CA-2012-124891 2012-07-31 2012-07-31
# Consumer           Australia    IN-2013-71249 2013-10-17 2013-10-18
# Consumer             Senegal     SG-2013-4320 2013-11-05 2013-11-06
# Consumer         New Zealand    IN-2011-81826 2011-11-07 2011-11-09
# Consumer         New Zealand    IN-2012-86369 2012-04-14 2012-04-18
# ...                      ...              ...        ...        ...
# Corporate             Mexico   MX-2011-130008 2011-12-09 2011-12-10
# Corporate              Spain  ES-2013-1247278 2013-12-17 2013-12-17
# Corporate        Philippines    ID-2014-61526 2014-12-20 2014-12-24
# Corporate      United States   CA-2013-101546 2013-12-19 2013-12-25
# Corporate      United States   CA-2014-154410 2014-10-22 2014-10-25
#
#                     Ship Mode Customer ID      Customer Name           City  \
# Customer Type
# ...

# %%
df = df.sort_index()  
df
# Out:
#                       Country         Order ID Order Date  Ship Date  \
# Customer Type
# Consumer        United States   CA-2012-124891 2012-07-31 2012-07-31
# Consumer       United Kingdom  ES-2014-4089082 2014-02-27 2014-03-03
# Consumer           Bangladesh    IN-2014-78725 2014-10-02 2014-10-06
# Consumer               Russia     RS-2013-7430 2013-08-15 2013-08-17
# Consumer             Thailand    IN-2013-42864 2013-11-19 2013-11-19
# ...                       ...              ...        ...        ...
# Home Office     United States   CA-2012-160227 2012-11-02 2012-11-04
# Home Office          Colombia   MX-2013-113824 2013-04-26 2013-04-28
# Home Office             India    IN-2012-26274 2012-02-27 2012-03-04
# Home Office         Nicaragua   MX-2013-141474 2013-10-30 2013-11-05
# Home Office           Vietnam    IN-2012-42220 2012-10-02 2012-10-02
#
#                     Ship Mode Customer ID       Customer Name  \
# Customer Type
# ...

# %%
df.loc[ 'Consumer' : 'Home Office' ]
# Out:
#                       Country         Order ID Order Date  Ship Date  \
# Customer Type
# Consumer        United States   CA-2012-124891 2012-07-31 2012-07-31
# Consumer       United Kingdom  ES-2014-4089082 2014-02-27 2014-03-03
# Consumer           Bangladesh    IN-2014-78725 2014-10-02 2014-10-06
# Consumer               Russia     RS-2013-7430 2013-08-15 2013-08-17
# Consumer             Thailand    IN-2013-42864 2013-11-19 2013-11-19
# ...                       ...              ...        ...        ...
# Home Office     United States   CA-2012-160227 2012-11-02 2012-11-04
# Home Office          Colombia   MX-2013-113824 2013-04-26 2013-04-28
# Home Office             India    IN-2012-26274 2012-02-27 2012-03-04
# Home Office         Nicaragua   MX-2013-141474 2013-10-30 2013-11-05
# Home Office           Vietnam    IN-2012-42220 2012-10-02 2012-10-02
#
#                     Ship Mode Customer ID       Customer Name  \
# Customer Type
# ...

# %% [markdown]
# ##

# %%
df = df.reset_index()
df
# Out:
#     Customer Type         Country         Order ID Order Date  Ship Date  \
# 0        Consumer   United States   CA-2012-124891 2012-07-31 2012-07-31
# 1        Consumer  United Kingdom  ES-2014-4089082 2014-02-27 2014-03-03
# 2        Consumer      Bangladesh    IN-2014-78725 2014-10-02 2014-10-06
# 3        Consumer          Russia     RS-2013-7430 2013-08-15 2013-08-17
# 4        Consumer        Thailand    IN-2013-42864 2013-11-19 2013-11-19
# ..            ...             ...              ...        ...        ...
# 823   Home Office   United States   CA-2012-160227 2012-11-02 2012-11-04
# 824   Home Office        Colombia   MX-2013-113824 2013-04-26 2013-04-28
# 825   Home Office           India    IN-2012-26274 2012-02-27 2012-03-04
# 826   Home Office       Nicaragua   MX-2013-141474 2013-10-30 2013-11-05
# 827   Home Office         Vietnam    IN-2012-42220 2012-10-02 2012-10-02
#
#           Ship Mode Customer ID       Customer Name              City  \
# ...

# %%
df = df.set_index(['Country','Customer Type'])
df
# Out:
#                                      Order ID Order Date  Ship Date  \
# Country        Customer Type
# United States  Consumer        CA-2012-124891 2012-07-31 2012-07-31
# United Kingdom Consumer       ES-2014-4089082 2014-02-27 2014-03-03
# Bangladesh     Consumer         IN-2014-78725 2014-10-02 2014-10-06
# Russia         Consumer          RS-2013-7430 2013-08-15 2013-08-17
# Thailand       Consumer         IN-2013-42864 2013-11-19 2013-11-19
# ...                                       ...        ...        ...
# United States  Home Office     CA-2012-160227 2012-11-02 2012-11-04
# Colombia       Home Office     MX-2013-113824 2013-04-26 2013-04-28
# India          Home Office      IN-2012-26274 2012-02-27 2012-03-04
# Nicaragua      Home Office     MX-2013-141474 2013-10-30 2013-11-05
# Vietnam        Home Office      IN-2012-42220 2012-10-02 2012-10-02
#
#                                    Ship Mode Customer ID       Customer Name  \
# Country        Customer Type
# ...

# %%
df.loc[ [('United States','Consumer')]  ]
# Out:
#                                    Order ID Order Date  Ship Date  \
# Country       Customer Type
# United States Consumer       CA-2012-124891 2012-07-31 2012-07-31
#               Consumer       CA-2014-143686 2014-05-15 2014-05-15
#               Consumer       CA-2011-116246 2011-09-12 2011-09-17
#               Consumer       CA-2014-160885 2014-12-03 2014-12-07
#               Consumer       CA-2014-120138 2014-05-26 2014-05-26
# ...                                     ...        ...        ...
#               Consumer       CA-2014-120376 2014-12-23 2014-12-26
#               Consumer       CA-2014-111556 2014-11-21 2014-11-23
#               Consumer       CA-2014-158379 2014-09-23 2014-09-27
#               Consumer       CA-2011-160766 2011-09-14 2011-09-14
#               Consumer       CA-2011-168494 2011-12-12 2011-12-14
#
#                                   Ship Mode Customer ID     Customer Name  \
# Country       Customer Type
# ...

# %%
df.loc[  [('United States','Consumer'),('India','Corporate')]  ].reset_index().to_excel('result.xlsx')

# %%
df
# Out:
#                                      Order ID Order Date  Ship Date  \
# Country        Customer Type
# United States  Consumer        CA-2012-124891 2012-07-31 2012-07-31
# United Kingdom Consumer       ES-2014-4089082 2014-02-27 2014-03-03
# Bangladesh     Consumer         IN-2014-78725 2014-10-02 2014-10-06
# Russia         Consumer          RS-2013-7430 2013-08-15 2013-08-17
# Thailand       Consumer         IN-2013-42864 2013-11-19 2013-11-19
# ...                                       ...        ...        ...
# United States  Home Office     CA-2012-160227 2012-11-02 2012-11-04
# Colombia       Home Office     MX-2013-113824 2013-04-26 2013-04-28
# India          Home Office      IN-2012-26274 2012-02-27 2012-03-04
# Nicaragua      Home Office     MX-2013-141474 2013-10-30 2013-11-05
# Vietnam        Home Office      IN-2012-42220 2012-10-02 2012-10-02
#
#                                    Ship Mode Customer ID       Customer Name  \
# Country        Customer Type
# ...

# %%
df['xyz']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xyz'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df['xyz']
#
# ...
