# %%
import pandas as pd

# %%
df =pd.read_excel('amazon.xlsx')
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %% [markdown]
# ## basic info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828 entries, 0 to 827
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       828 non-null    object
#  1   Order Date     828 non-null    datetime64[ns]
#  2   Ship Date      828 non-null    datetime64[ns]
#  3   Ship Mode      828 non-null    object
#  4   Customer ID    828 non-null    object
#  5   Customer Name  828 non-null    object
#  6   Customer Type  828 non-null    object
#  7   City           828 non-null    object
#  8   State          828 non-null    object
#  9   Country        828 non-null    object
#  10  Product Type   828 non-null    object
#  11  Product        828 non-null    object
#  12  Product Name   828 non-null    object
#  13  Sales          828 non-null    float64
#  14  Quantity       828 non-null    int64
#  15  Discount       828 non-null    float64
#  16  Profit         828 non-null    float64
# ...

# %% [markdown]
# ## top N rows

# %%
df.head(1)
# Out:
#          Order ID Order Date  Ship Date Ship Mode Customer ID Customer Name  \
# 0  CA-2012-124891 2012-07-31 2012-07-31  Same Day    RH-19495   Rick Hansen
#
#   Customer Type           City     State        Country Product Type  \
# 0      Consumer  New York City  New York  United States   Technology
#
#        Product                                       Product Name    Sales  \
# 0  Accessories  Plantronics CS510 - Over-the-Head monaural Wir...  2309.65
#
#    Quantity  Discount    Profit  Shipping Cost
# 0         7       0.0  762.1845         933.57

# %% [markdown]
# # Bottom N Rows

# %%
df.tail(2)
# Out:
#           Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 826  IN-2013-65677 2013-10-11 2013-10-14   First Class    HD-14785
# 827  ID-2012-39875 2012-04-25 2012-04-27  Second Class    TP-21130
#
#         Customer Name Customer Type      City     State Country Product Type  \
# 826     Harold Dahlen   Home Office  Shanghai  Shanghai   China   Technology
# 827  Theone Pippenger      Consumer  Mianyang   Sichuan   China    Furniture
#
#       Product                           Product Name    Sales  Quantity  \
# 826  Machines                 Epson Inkjet, Wireless   924.66         3
# 827    Tables  Barricks Round Table, Fully Assembled  1760.43         5
#
#      Discount  Profit  Shipping Cost
# 826       0.0  397.53          225.0
# 827       0.3 -326.97          224.8

# %% [markdown]
# ## statistical Summary

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                            828                            828
# mean   2013-05-24 14:31:18.260869632  2013-05-27 09:54:46.956521728
# min              2011-01-07 00:00:00            2011-01-11 00:00:00
# 25%              2012-06-22 12:00:00            2012-06-25 18:00:00
# 50%              2013-07-15 00:00:00            2013-07-16 12:00:00
# 75%              2014-06-03 00:00:00            2014-06-05 12:00:00
# max              2014-12-31 00:00:00            2015-01-03 00:00:00
# std                              NaN                            NaN
#
#               Sales    Quantity    Discount       Profit  Shipping Cost
# count    828.000000  828.000000  828.000000   828.000000     828.000000
# mean    2280.197907    6.134058    0.088012   401.654958     363.300859
# min      473.847000    1.000000    0.000000 -6599.978000     224.800000
# ...
