# %%
import pandas as pd

# %%
df=pd.read_excel('Employee-data.xlsx')
df
# Out:
#      Unnamed: 0     name   age  height  weight gender  married   income  \
# 0             0    Alice  25.0   162.5    55.3      F    False      NaN
# 1             1      Bob  32.0   178.2    72.1      M     True  45000.0
# 2             2  Charlie   NaN   168.9     NaN      M     True  67000.0
# 3             3    David  47.0   155.7    63.5      M    False  28000.0
# 4             4      Eva   NaN     NaN    57.9      F     True  55000.0
# ..          ...      ...   ...     ...     ...    ...      ...      ...
# 991         991      Bob  32.0   178.2    72.1      M     True  45000.0
# 992         992  Charlie   NaN   168.9     NaN      M     True  67000.0
# 993         993    David  47.0   155.7    63.5      M    False  28000.0
# 994         994      Eva   NaN     NaN    57.9      F     True  55000.0
# 995         995    Frank  23.0   170.1     NaN      M    False  32000.0
#
#        hobby  is_student              start_date                end_date  \
# ...

# %% [markdown]
# Drop the 'hobby' column from the dataframe.

# %%
df.drop(columns='hobby')
# Out:
#      Unnamed: 0     name   age  height  weight gender  married   income  \
# 0             0    Alice  25.0   162.5    55.3      F    False      NaN
# 1             1      Bob  32.0   178.2    72.1      M     True  45000.0
# 2             2  Charlie   NaN   168.9     NaN      M     True  67000.0
# 3             3    David  47.0   155.7    63.5      M    False  28000.0
# 4             4      Eva   NaN     NaN    57.9      F     True  55000.0
# ..          ...      ...   ...     ...     ...    ...      ...      ...
# 991         991      Bob  32.0   178.2    72.1      M     True  45000.0
# 992         992  Charlie   NaN   168.9     NaN      M     True  67000.0
# 993         993    David  47.0   155.7    63.5      M    False  28000.0
# 994         994      Eva   NaN     NaN    57.9      F     True  55000.0
# 995         995    Frank  23.0   170.1     NaN      M    False  32000.0
#
#      is_student              start_date                end_date  is_employed
# ...

# %% [markdown]
# Drop the first row from the dataframe.

# %%
df.drop(index=0)
# Out:
#      Unnamed: 0     name   age  height  weight gender  married   income  \
# 1             1      Bob  32.0   178.2    72.1      M     True  45000.0
# 2             2  Charlie   NaN   168.9     NaN      M     True  67000.0
# 3             3    David  47.0   155.7    63.5      M    False  28000.0
# 4             4      Eva   NaN     NaN    57.9      F     True  55000.0
# 5             5    Frank  23.0   170.1     NaN      M    False  32000.0
# ..          ...      ...   ...     ...     ...    ...      ...      ...
# 991         991      Bob  32.0   178.2    72.1      M     True  45000.0
# 992         992  Charlie   NaN   168.9     NaN      M     True  67000.0
# 993         993    David  47.0   155.7    63.5      M    False  28000.0
# 994         994      Eva   NaN     NaN    57.9      F     True  55000.0
# 995         995    Frank  23.0   170.1     NaN      M    False  32000.0
#
#        hobby  is_student              start_date                end_date  \
# ...

# %% [markdown]
# Drop the name , age and hobby column from the dataframe.

# %%
df.drop(columns=['name','age','hobby'])
# Out:
#      Unnamed: 0  height  weight gender  married   income  is_student  \
# 0             0   162.5    55.3      F    False      NaN        True
# 1             1   178.2    72.1      M     True  45000.0       False
# 2             2   168.9     NaN      M     True  67000.0       False
# 3             3   155.7    63.5      M    False  28000.0        True
# 4             4     NaN    57.9      F     True  55000.0       False
# ..          ...     ...     ...    ...      ...      ...         ...
# 991         991   178.2    72.1      M     True  45000.0       False
# 992         992   168.9     NaN      M     True  67000.0       False
# 993         993   155.7    63.5      M    False  28000.0        True
# 994         994     NaN    57.9      F     True  55000.0       False
# 995         995   170.1     NaN      M    False  32000.0        True
#
#                  start_date                end_date  is_employed
# 0   2024-12-15 15:42:42.162 2022-06-07 20:06:29.189          0.0
# ...
