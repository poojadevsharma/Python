# %%
import pandas as pd

# %%
df = pd.read_excel('amazon.xlsx')
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %% [markdown]
# iloc - index location

# %% [markdown]
# # Starting 4 Rows and Starting 3 Columns

# %%
df.head(4)[['Order ID','Order Date','Ship Date']]
# Out:
#           Order ID Order Date  Ship Date
# 0   CA-2012-124891 2012-07-31 2012-07-31
# 1    IN-2013-77878 2013-02-05 2013-02-07
# 2    IN-2013-71249 2013-10-17 2013-10-18
# 3  ES-2013-1579342 2013-01-28 2013-01-30

# %% [markdown]
# iloc

# %%
df.iloc[ 0:4 , 0:3 ]
# Out:
#           Order ID Order Date  Ship Date
# 0   CA-2012-124891 2012-07-31 2012-07-31
# 1    IN-2013-77878 2013-02-05 2013-02-07
# 2    IN-2013-71249 2013-10-17 2013-10-18
# 3  ES-2013-1579342 2013-01-28 2013-01-30

# %%
df.iloc[100:201,-3:]
# Out:
#      Discount     Profit  Shipping Cost
# 100      0.00  1465.2000        533.990
# 101      0.10   861.3720        531.280
# 102      0.15   790.4160        531.090
# 103      0.00   178.9200        530.486
# 104      0.00   308.4000        527.870
# ..        ...        ...            ...
# 196      0.10   134.3040        428.830
# 197      0.00   792.2691        428.800
# 198      0.10  1644.0300        427.460
# 199      0.10   -11.9340        427.240
# 200      0.00     0.0000        427.100
#
# [101 rows x 3 columns]

# %% [markdown]
# loc

# %% [markdown]
# # Customers who purchased > 2000

# %%
df.loc[ df['Sales']>2000  ]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 808    IN-2014-47806 2014-05-17 2014-05-22    Second Class    DO-13435
# 812    IN-2014-76016 2014-09-26 2014-09-28    Second Class    VG-21805
# 813    IN-2012-45909 2012-10-05 2012-10-09  Standard Class    TB-21190
# 819  ES-2013-1247278 2013-12-17 2013-12-17        Same Day    VP-21760
# 820  ES-2014-5218647 2014-04-14 2014-04-18  Standard Class    EG-13900
#
#         Customer Name Customer Type                City              State  \
# ...

# %%
df.loc[df['Customer Type']=='Consumer']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 6      IN-2011-81826 2011-11-07 2011-11-09     First Class    TS-21340
# 7      IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
# ..               ...        ...        ...             ...         ...
# 816     IV-2014-5230 2014-12-10 2014-12-13    Second Class    SV-10785
# 818   CA-2013-165330 2013-12-12 2013-12-12        Same Day    WB-21850
# 820  ES-2014-5218647 2014-04-14 2014-04-18  Standard Class    EG-13900
# 822    IN-2013-10811 2013-09-17 2013-09-20     First Class    LR-16915
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#         Customer Name Customer Type           City           State  \
# ...

# %% [markdown]
# # Consumer who purchased more than 2000

# %%
ndf = df.loc[df['Customer Type']=='Consumer']
ndf  =  ndf.loc[ndf['Sales']>2000]
ndf
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 7      IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
# 9     CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
# ..               ...        ...        ...             ...         ...
# 763  ES-2013-3061639 2013-06-27 2013-06-27        Same Day    ES-14020
# 789      SA-2012-730 2012-06-25 2012-07-01  Standard Class     MS-7830
# 793   MX-2013-109883 2013-09-03 2013-09-09  Standard Class    DC-13285
# 808    IN-2014-47806 2014-05-17 2014-05-22    Second Class    DO-13435
# 820  ES-2014-5218647 2014-04-14 2014-04-18  Standard Class    EG-13900
#
#      Customer Name Customer Type           City              State  \
# ...

# %% [markdown]
# and    &
#
# or     |

# %%
df.loc[ (df['Customer Type']=='Consumer') & (df['Sales']>2000)  ]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 7      IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
# 9     CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
# ..               ...        ...        ...             ...         ...
# 763  ES-2013-3061639 2013-06-27 2013-06-27        Same Day    ES-14020
# 789      SA-2012-730 2012-06-25 2012-07-01  Standard Class     MS-7830
# 793   MX-2013-109883 2013-09-03 2013-09-09  Standard Class    DC-13285
# 808    IN-2014-47806 2014-05-17 2014-05-22    Second Class    DO-13435
# 820  ES-2014-5218647 2014-04-14 2014-04-18  Standard Class    EG-13900
#
#      Customer Name Customer Type           City              State  \
# ...

# %%
df.loc[ (df['Customer Type']=='Consumer')  |   (df['Customer Type']=='Corporate')  ]
# Out:
#            Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1     IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2     IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 4      SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 5     IN-2013-42360 2013-06-28 2013-07-01    Second Class    JM-15655
# ..              ...        ...        ...             ...         ...
# 821   ID-2014-61526 2014-12-20 2014-12-24  Standard Class    TC-21145
# 822   IN-2013-10811 2013-09-17 2013-09-20     First Class    LR-16915
# 823  CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824  CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 827   ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %%
df.loc[ df['State']!='New York' ]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 5      IN-2013-42360 2013-06-28 2013-07-01    Second Class    JM-15655
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type          City            State  \
# ...

# %%
# City and State of Consumers who have purchased more than 5000

# %%
df.loc[(df['Customer Type']=='Consumer') & (df['Sales']>5000)][['City','State']]
# Out:
#                  City               State
# 2            Brisbane          Queensland
# 7            Hamilton             Waikato
# 43       Huddersfield             England
# 45        Minneapolis           Minnesota
# 64               Wuxi             Jiangsu
# 76            Atlanta             Georgia
# 80              Lille  Nord-Pas-de-Calais
# 82            Jackson            Michigan
# 121     New York City            New York
# 122           Detroit            Michigan
# 127      Philadelphia        Pennsylvania
# 162            Jeddah              Makkah
# 168            London             England
# 192  Stockton-on-Tees             England
# 223          Shaoxing            Zhejiang
# 290            Newark            Delaware
# 313              Kota        Chhattisgarh
# 334            Sydney     New South Wales
# 344       San Antonio               Texas
# 609           Beijing             Beijing

# %%
a = 'abhishek'
a.upper()
# Out:
# 'ABHISHEK'

# %%
'abhishek'.upper().replace('A','T')   #'ABHISHEK'
# Out:
# 'TBHISHEK'
